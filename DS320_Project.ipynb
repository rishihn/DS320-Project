# %% [markdown]
# <a href="https://colab.research.google.com/github/rishihn/DS320-Project/blob/main/DS320_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

imdb = pd.read_csv('imdb_top_1000.csv')
imdb.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
import pandas as pd

movies = pd.read_csv('top_4000_movies_data.csv')
movies.head()
# Out:
#   Release Date                                  Movie Title  \
# 0    4/23/2019                            Avengers: Endgame
# 1    5/20/2011  Pirates of the Caribbean: On Stranger Tides
# 2    4/22/2015                      Avengers: Age of Ultron
# 3   12/16/2015         Star Wars Ep. VII: The Force Awakens
# 4    4/25/2018                       Avengers: Infinity War
#
#    Production Budget  Domestic Gross  Worldwide Gross
# 0          400000000       858373000       2797800564
# 1          379000000       241071802       1045713802
# 2          365000000       459005868       1395316979
# 3          306000000       936662225       2064615817
# 4          300000000       678815482       2044540523

# %% [markdown]
# Clean up and only highlight relevant info for imdb data set

# %%
#imdb dataset: drop unneccesary columns and any NaN values
imdb_clean = imdb.drop(columns=['Poster_Link', 'Meta_score', 'Certificate', 'Overview', 'Star1', 'Star2', 'Star3', 'Star4'])
imdb_clean = imdb_clean.dropna()

#Change runtime from 142 min to just the integer
imdb_clean['Runtime'] = imdb_clean['Runtime'].str.extract('(\d+)').astype(int)

#Remove any commas or special characters from gross column
imdb_clean['Gross'] = imdb_clean['Gross'].replace('[\$,]', '', regex=True)

#Lowercase movie titles and remove any special characters like ':'
imdb_clean['Series_Title'] = imdb_clean['Series_Title'].replace('[\$,:]', '', regex=True)
imdb_clean['Series_Title'] = imdb_clean['Series_Title'].str.lower()

#rename Series_Title to just title
imdb_clean = imdb_clean.rename(columns={'Series_Title': 'title'})

imdb_clean['Genre'] = imdb_clean['Genre'].apply(lambda x: x.split(',')[0].strip())

#return cleaned dataset
imdb_clean.to_csv('imdb_clean.csv', index=False)
imdb_clean
# Out:
#                         title Released_Year  Runtime      Genre  IMDB_Rating  \
# 0    the shawshank redemption          1994      142      Drama          9.3
# 1               the godfather          1972      175      Crime          9.2
# 2             the dark knight          2008      152     Action          9.0
# 3       the godfather part ii          1974      202      Crime          9.0
# 4                12 angry men          1957       96      Crime          9.0
# ..                        ...           ...      ...        ...          ...
# 990              giù la testa          1971      157      Drama          7.6
# 991            kelly's heroes          1970      144  Adventure          7.6
# 992           the jungle book          1967       78  Animation          7.6
# 994        a hard day's night          1964       87     Comedy          7.6
# 997     from here to eternity          1953      118      Drama          7.6
#
# ...

# %%
#movies_cleaned = movies.drop(columns=['Release Date'])


# Remove rows with missing values
movies_cleaned = movies.dropna()


# Format the "Movie Title"
# Remove special characters like ':', and convert to lowercase
movies_cleaned['Movie Title'] = movies_cleaned['Movie Title'].replace('[$,:]', '', regex=True)
movies_cleaned['Movie Title'] = movies_cleaned['Movie Title'].str.lower()

# Return only the year in the release date
movies_cleaned['Release Date'] = movies_cleaned['Release Date'].str[-4:]

# Change Production Budget to return in millions
movies_cleaned['Production Budget'] = movies_cleaned['Production Budget'] / 1000000

# Rename 'Movie Title' to 'title', 'Release Date' to 'year', 'Production Budget' to 'Production Budget (mil)'
movies_cleaned = movies_cleaned.rename(columns={'Movie Title': 'title'})
movies_cleaned = movies_cleaned.rename(columns={'Release Date': 'year'})
movies_cleaned = movies_cleaned.rename(columns={'Production Budget': 'Production Budget (mil)'})

movies_cleaned.to_csv('movies_cleaned.csv', index=False)
movies_cleaned
# Out:
# <ipython-input-10-dc31fbc917d7>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_cleaned['Movie Title'] = movies_cleaned['Movie Title'].replace('[$,:]', '', regex=True)
# <ipython-input-10-dc31fbc917d7>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_cleaned['Movie Title'] = movies_cleaned['Movie Title'].str.lower()
# <ipython-input-10-dc31fbc917d7>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
